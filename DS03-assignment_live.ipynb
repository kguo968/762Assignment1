# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import dslab
# Out:
# /opt/anaconda3/envs/term121x_env/bin/python
# {'numpy': '1.20.1', 'pandas': '1.1.3', 'seaborn': '0.11.0', 'sklearn': '0.23.2', 'matplotlib': '3.3.1'}

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
def load_data(fn='train.csv'):
    return pd.read_csv(fn, index_col=0, na_values='NaN', keep_default_na=False)

load_data()
# Out:
#        MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# Order
# 1474           60       RL          65     8450   Pave    NA      Reg
# 1860           20       RL          80     9600   Pave    NA      Reg
# 1444           60       RL          68    11250   Pave    NA      IR1
# 2858           70       RL          60     9550   Pave    NA      IR1
# 1101           60       RL          84    14260   Pave    NA      IR1
# ...           ...      ...         ...      ...    ...   ...      ...
# 1756           60       RL          62     7917   Pave    NA      Reg
# 20             20       RL          85    13175   Pave    NA      Reg
# 296            70       RL          66     9042   Pave    NA      Reg
# 127            20       RL          68     9717   Pave    NA      Reg
# 1489           20       RL          75     9937   Pave    NA      Reg
#
#       LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
from dslab.visualization.visualize import distribution

distribution(df['SalePrice'])
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  (<AxesSubplot:>, <AxesSubplot:xlabel='SalePrice'>))

# %%
y = pd.Series(np.log(df['SalePrice']), name='actual_log_price')
y
# Out:
# Order
# 1474    12.247694
# 1860    12.109011
# 1444    12.317167
# 2858    11.849398
# 1101    12.429216
#           ...
# 1756    12.072541
# 20      12.254863
# 296     12.493130
# 127     11.864462
# 1489    11.901583
# Name: actual_log_price, Length: 1460, dtype: float64

# %%
distribution(y)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  (<AxesSubplot:>, <AxesSubplot:xlabel='actual_log_price'>))

# %%
df.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
distribution(df['LotArea'])
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  (<AxesSubplot:>, <AxesSubplot:xlabel='LotArea'>))

# %%
X = pd.DataFrame({'log_LotArea': np.log(df['LotArea'])})
X
# Out:
#        log_LotArea
# Order
# 1474      9.041922
# 1860      9.169518
# 1444      9.328123
# 2858      9.164296
# 1101      9.565214
# ...            ...
# 1756      8.976768
# 20        9.486076
# 296       9.109636
# 127       9.181632
# 1489      9.204020
#
# [1460 rows x 1 columns]

# %%
distribution(X['log_LotArea'])
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  (<AxesSubplot:>, <AxesSubplot:xlabel='log_LotArea'>))

# %%
distribution(df['YearBuilt'])
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  (<AxesSubplot:>, <AxesSubplot:xlabel='YearBuilt'>))

# %%
def generate_feature_matrix(df):
    result = pd.DataFrame({'log_LotArea': np.log(df['LotArea']),
                 'centered_YearBuilt': df['YearBuilt'] - np.median(df['YearBuilt'])})
    return result

# %%
X = generate_feature_matrix(df)

# %%
Xtest = generate_feature_matrix(test)

# %%
X
# Out:
#        log_LotArea  centered_YearBuilt
# Order
# 1474      9.041922                30.0
# 1860      9.169518                 3.0
# 1444      9.328123                28.0
# 2858      9.164296               -58.0
# 1101      9.565214                27.0
# ...            ...                 ...
# 1756      8.976768                26.0
# 20        9.486076                 5.0
# 296       9.109636               -32.0
# 127       9.181632               -23.0
# 1489      9.204020                -8.0
#
# [1460 rows x 2 columns]

# %%
distribution(X['centered_YearBuilt'])
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  (<AxesSubplot:>, <AxesSubplot:xlabel='centered_YearBuilt'>))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([0.29883307, 0.00764619]), 9.314696564764649)

# %%
X.head()
# Out:
#        log_LotArea  centered_YearBuilt
# Order
# 1474      9.041922                30.0
# 1860      9.169518                 3.0
# 1444      9.328123                28.0
# 2858      9.164296               -58.0
# 1101      9.565214                27.0

# %%
y_pred = model.predict(X)

# %%
plt.plot(y_pred, y, 'o', alpha=0.2)
plt.xlabel('predicted log SalePrice')
plt.ylabel('actual log SalePrice')
# Out:
# Text(0, 0.5, 'actual log SalePrice')

# %%
y_test = np.exp(model.predict(Xtest))
y_test
# Out:
# array([166078.46573718, 172569.02895956, 230373.55669087, ...,
#        193839.49172865, 203867.30423726, 200509.09409331])

# %%
prediction = pd.Series(y_test, Xtest.index)
prediction
# Out:
# Id
# 1461    166078.465737
# 1462    172569.028960
# 1463    230373.556691
# 1464    210564.505765
# 1465    163651.059540
#             ...
# 2915    104134.645906
# 2916    103454.347663
# 2917    193839.491729
# 2918    203867.304237
# 2919    200509.094093
# Length: 1459, dtype: float64

# %%
prediction.to_csv('prediction.csv')
